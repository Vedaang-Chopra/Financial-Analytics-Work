# %% [markdown]
# ### Basic Python Imports

# %%
import pandas as pd
import numpy as np

# %%
import os

# %% [markdown]
# ### Setting File Paths

# %%
BASE_CODE_FOLDER=os.sep.join(os.getcwd().split(os.sep)[:os.getcwd().split(os.sep).index('Mutual_Fund_Analysis')+1])
DATASET_FOLDER=os.path.join(BASE_CODE_FOLDER, 'Dataset')
LIST_OF_MUTUAL_FUNDS=os.path.join(DATASET_FOLDER,'list_of_mutual_funds')
AMFI_REPORTS=os.path.join(LIST_OF_MUTUAL_FUNDS,'amfi_reports')

# %%
os.listdir(AMFI_REPORTS)
# Out:
# ['AMFI_Reports.xls']

# %% [markdown]
# ### Importing  Basic Data

# %%
print(os.path.join(AMFI_REPORTS, os.listdir(AMFI_REPORTS)[0]))
CURRENT_DATA=pd.read_html(os.path.join(AMFI_REPORTS, os.listdir(AMFI_REPORTS)[0]),header=0)
CURRENT_DATA=pd.DataFrame(CURRENT_DATA[0])
CURRENT_DATA.head()
# CURRENT_DATA.to_csv('temp_print.csv')
# Out:
# d:\Artificial Intelligence\Code Repository\External_Datasets_for_All_Projects\All_Projects_Implemented\Large_Projects\Mutual_Fund_Analysis\list_of_mutual_funds\amfi_reports\AMFI_Reports.xls
#                              Latest Net Asset Values  \
# 0                                    Scheme NAV Name
# 1  Open Ended Schemes (Debt Scheme - Banking and ...
# 2                  Aditya Birla Sun Life Mutual Fund
# 3  Aditya Birla Sun Life Banking & PSU Debt Fund-...
# 4  Aditya Birla Sun Life Banking & PSU Debt Fund-...
#
#                            Latest Net Asset Values.1  \
# 0                       ISIN Div Payout/ ISIN Growth
# 1  Open Ended Schemes (Debt Scheme - Banking and ...
# 2                  Aditya Birla Sun Life Mutual Fund
# 3                                       INF209KA12Z1
# 4                                       INF209K01YM2
#
#                            Latest Net Asset Values.2  \
# 0                               ISIN DivReinvestment
# 1  Open Ended Schemes (Debt Scheme - Banking and ...
# 2                  Aditya Birla Sun Life Mutual Fund
# 3                                       INF209KA13Z9
# 4                                                NaN
#
#                            Latest Net Asset Values.3  \
# 0                                    Net Asset Value
# 1  Open Ended Schemes (Debt Scheme - Banking and ...
# 2                  Aditya Birla Sun Life Mutual Fund
# 3                                           110.3887
# 4                                           113.8611
#
#                            Latest Net Asset Values.4  \
# 0                                               Date
# 1  Open Ended Schemes (Debt Scheme - Banking and ...
# 2                  Aditya Birla Sun Life Mutual Fund
# 3                                        31-Mar-2023
# 4                                        31-Mar-2023
#
#                            Latest Net Asset Values.5  \
# 0                                                NaN
# 1  Open Ended Schemes (Debt Scheme - Banking and ...
# 2                  Aditya Birla Sun Life Mutual Fund
# 3                                                NaN
# 4                                                NaN
#
#                            Latest Net Asset Values.6
# 0                                                NaN
# 1  Open Ended Schemes (Debt Scheme - Banking and ...
# 2                  Aditya Birla Sun Life Mutual Fund
# 3                                                NaN
# 4                                                NaN

# %%
# BASIC_AMFI_REPORT=[]
# def fixing_amfi_reports_file_headers(AMFI_DATA):
#     initial_headers=AMFI_DATA.columns.values
#     initial_headers
#     temp=[]
#     temp.append([initial_headers[0][0], "", "", "", ""])    
#     temp.append([initial_headers[0][1], initial_headers[1][1], initial_headers[2][1], initial_headers[3][1],initial_headers[3][1]])
#     temp.append([initial_headers[0][2], "", "", "", ""])
#     temp.append([initial_headers[0][3], "", "", "", ""]) 
#     return temp
# BASIC_AMFI_REPORT+=fixing_amfi_reports_file_headers(CURRENT_DATA)
# pd.concat(BASIC_AMFI_REPORT, CURRENT_DATA)

# %%
# print(os.path.join(AMFI_REPORTS, os.listdir(AMFI_REPORTS)[0]))
# CURRENT_DATA_CSV=pd.read_csv(os.path.join(AMFI_REPORTS, os.listdir(AMFI_REPORTS)[0]))
# CURRENT_DATA_CSV.head()

# %%
def isNaN(num):
    return num != num

# %%
def identify_complete_fund_categories(FUND_HEADER):
    TYPE= FUND_HEADER.split("(")[0].strip()
    if FUND_HEADER.__contains__("-"):
        CATEGORY = FUND_HEADER.split("(")[1].split(")")[0].split("-")[0].strip()
        SUB_CATEGORY =FUND_HEADER.split("(")[1].split(")")[0].split("-")[1].strip()
    else:
        CATEGORY = FUND_HEADER.split("(")[1].split(")")[0].strip()
        SUB_CATEGORY=""
    return TYPE, CATEGORY, SUB_CATEGORY

# %%
MUTUAL_FUND_DATA_TEMP=[]
# c=0
for i in range(0,len(CURRENT_DATA)):
    CURRENT_TEXT= (CURRENT_DATA.iloc[i][0])
    if isNaN(CURRENT_DATA.iloc[i][1]) and isNaN(CURRENT_DATA.iloc[i][2]) and isNaN(CURRENT_DATA.iloc[i][3]):
        if CURRENT_TEXT.__contains__ ("Open Ended") or CURRENT_TEXT.__contains__ ("Close Ended") or CURRENT_TEXT.__contains__ ("Interval Fund Schemes"):
            # print("Category:", CURRENT_TEXT)
            TYPE, CATEGORY, SUB_CATEGORY = identify_complete_fund_categories(CURRENT_TEXT)
            # c=c+1
            # pass
        elif CURRENT_TEXT.__contains__("Mutual Fund") and CURRENT_TEXT==CURRENT_DATA.iloc[i][1]:
            # print("Fund AMC:", CURRENT_TEXT)
            FUND_AMC=CURRENT_TEXT
            # pass
        else:
            print("Header Column, to be Ignored")
            # print(CURRENT_DATA.iloc[i].values)
    elif CURRENT_DATA.iloc[i][1]==CURRENT_DATA.iloc[i][2]==CURRENT_DATA.iloc[i][3]:
        if CURRENT_TEXT.__contains__ ("Open Ended") or CURRENT_TEXT.__contains__ ("Close Ended") or CURRENT_TEXT.__contains__ ("Interval Fund Schemes"):
            # print("Category:", CURRENT_TEXT)
            TYPE, CATEGORY, SUB_CATEGORY = identify_complete_fund_categories(CURRENT_TEXT)
            # c=c+1
            # pass
        elif CURRENT_TEXT.__contains__("Mutual Fund") and CURRENT_TEXT==CURRENT_DATA.iloc[i][1]:
            # print("Fund AMC:", CURRENT_TEXT)
            FUND_AMC=CURRENT_TEXT
            # pass
        else:
            print("Header Column, to be Ignored")
    else:
        
        if isNaN(CURRENT_TEXT) or CURRENT_TEXT.strip()=='Scheme NAV Name' :
            continue
        else:
            # print(CURRENT_TEXT, CURRENT_DATA.iloc[i][1])
            SCHEME_NAV_NAME=CURRENT_TEXT
            ISIN_DIV_GROWTH=CURRENT_DATA.iloc[i][1]
            ISIN_DIV_REINIVESTMENT=CURRENT_DATA.iloc[i][2]
            NAV_VALUE=CURRENT_DATA.iloc[i][3]
            DATE_RECORDED=CURRENT_DATA.iloc[i][4]
            MUTUAL_FUND_DATA_TEMP.append([FUND_AMC, SCHEME_NAV_NAME, TYPE, CATEGORY, SUB_CATEGORY, ISIN_DIV_GROWTH, ISIN_DIV_REINIVESTMENT, NAV_VALUE, DATE_RECORDED])

# %%
MUTUAL_FUND_FINAL_DATA=pd.DataFrame(columns=["Mutual Fund Name", "Scheme NAV Name","FUND TYPE","FUND CATEGORY", "FUND SUB-CATEGORY", "ISIN Div Payout/ ISIN Growth", "ISIN Div Reinvestment", "Net Asset Value", "Date"])

# %%
CLEAN_DATA=pd.DataFrame(MUTUAL_FUND_DATA_TEMP, columns=["Mutual Fund Name", "Scheme NAV Name","FUND TYPE","FUND CATEGORY", "FUND SUB-CATEGORY", "ISIN Div Payout/ ISIN Growth", "ISIN Div Reinvestment", "Net Asset Value", "Date"])
CLEAN_DATA
# Out:
#                         Mutual Fund Name  \
# 0      Aditya Birla Sun Life Mutual Fund
# 1      Aditya Birla Sun Life Mutual Fund
# 2      Aditya Birla Sun Life Mutual Fund
# 3      Aditya Birla Sun Life Mutual Fund
# 4      Aditya Birla Sun Life Mutual Fund
# ...                                  ...
# 12829           Nippon India Mutual Fund
# 12830           Nippon India Mutual Fund
# 12831           Nippon India Mutual Fund
# 12832           Nippon India Mutual Fund
# 12833           Nippon India Mutual Fund
#
#                                          Scheme NAV Name  \
# 0      Aditya Birla Sun Life Banking & PSU Debt Fund-...
# 1      Aditya Birla Sun Life Banking & PSU Debt Fund-...
# 2      Aditya Birla Sun Life Banking & PSU Debt Fund-...
# 3      Aditya Birla Sun Life Banking & PSU Debt Fund-...
# 4      Aditya Birla Sun Life Banking & PSU Debt Fund-...
# ...                                                  ...
# 12829  Reliance Interval Fund -IV -Series 2 - Growth ...
# 12830  Reliance Interval Fund IV- Series 3- Direct Pl...
# 12831  Reliance Interval Fund IV- Series 3- Direct Pl...
# 12832  Reliance Interval Fund IV- Series 3- Dividend ...
# 12833  Reliance Interval Fund IV- Series 3- Growth op...
#
#                    FUND TYPE FUND CATEGORY     FUND SUB-CATEGORY  \
# 0         Open Ended Schemes   Debt Scheme  Banking and PSU Fund
# 1         Open Ended Schemes   Debt Scheme  Banking and PSU Fund
# 2         Open Ended Schemes   Debt Scheme  Banking and PSU Fund
# 3         Open Ended Schemes   Debt Scheme  Banking and PSU Fund
# 4         Open Ended Schemes   Debt Scheme  Banking and PSU Fund
# ...                      ...           ...                   ...
# 12829  Interval Fund Schemes        Income
# 12830  Interval Fund Schemes        Income
# 12831  Interval Fund Schemes        Income
# 12832  Interval Fund Schemes        Income
# 12833  Interval Fund Schemes        Income
#
#       ISIN Div Payout/ ISIN Growth ISIN Div Reinvestment Net Asset Value  \
# 0                     INF209KA12Z1          INF209KA13Z9        110.3887
# 1                     INF209K01YM2                   NaN        113.8611
# 2                     INF209K01YO8                   NaN        111.3111
# 3                     INF209K01LX6          INF209KA11Z3        156.2795
# 4                     INF209K01LU2                   NaN        110.6432
# ...                            ...                   ...             ...
# 12829                 INF204KA11F6                   NaN          12.721
# 12830                 INF204KA14I4                   NaN         12.6668
# 12831                 INF204KA15I1                   NaN         12.6668
# 12832                 INF204KA12I8                   NaN         12.4325
# 12833                 INF204KA13I6                   NaN         12.4325
#
#               Date
# 0      31-Mar-2023
# 1      31-Mar-2023
# 2      31-Mar-2023
# 3      31-Mar-2023
# 4      31-Mar-2023
# ...            ...
# 12829  02-Jul-2018
# 12830  02-Jul-2018
# 12831  02-Jul-2018
# 12832  02-Jul-2018
# 12833  02-Jul-2018
#
# [12834 rows x 9 columns]

# %%
# CLEAN_DATA.to_csv("temp_print.csv")

# %%
# from sqlalchemy import create_engine
# import psycopg2
# engine = create_engine('postgresql://postgres:postgrespw@localhost:32768')
# CLEAN_DATA.to_sql('demo_mutual_fund_data', engine)
# Out:
# 834

# %%
# from elasticsearch import Elasticsearch
# from elasticsearch import helpers
# es = Elasticsearch(http_compress=True)

# %%
# es = Elasticsearch(hosts='127.0.0.1',http_compress=True)

# %%
# def doc_generator(df):
#     json_data=CLEAN_DATA.to_dict(orient="index")
#     df_iter = df.iterrows()
#     for index, document in json_data:
#         yield {
#                 "_index": 'your_index',
#                 "_type": "_doc",
#                 "_source": document,
#             }
#     raise StopIteration
# helpers.bulk(es_client, doc_generator(json_data))
# doc_generator(CLEAN_DATA)
