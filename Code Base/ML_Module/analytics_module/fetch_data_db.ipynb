# %%
import influxdb_client, os, time
from influxdb_client import InfluxDBClient, Point, WritePrecision
from influxdb_client.client.write_api import SYNCHRONOUS
from influxdb_client.client.exceptions import InfluxDBError

# %%
INFLUXDB_TOKEN="CdNR2m9lhVe4OlM2sS8BDzXVVqgEcE9RZa5vZpz5OCUnkNZnEcyS4TrFjZVtzBDYD2JjxyYY1XPP0idn9owOkg=="
token = INFLUXDB_TOKEN
org = "Mutual Fund Data Collection"
url = "http://127.0.0.1:8086"
bucket="mutual_fund_nav_data"
write_client = influxdb_client.InfluxDBClient(url=url, token=token, org=org)
write_api = write_client.write_api(write_options=SYNCHRONOUS)

# %%
query_api = write_client.query_api()
query = 'from(bucket:"'+bucket+'")\
|> range(start: -1d)\
|> filter(fn:(r) => r._measurement == "Aditya Birla Sun Life Mutual Fund")'
print(query)
# query="SELECT * FROM 'quant Mutual Fund';"
result = query_api.query(org=org, query=query)
for table in result:
    for record in table.records:
        print(record)
# Out:
# from(bucket:"mutual_fund_nav_data")|> range(start: -1d)|> filter(fn:(r) => r._measurement == "Aditya Birla Sun Life Mutual Fund")
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 18.8475, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla SUn Life Global Emerging Opportunities Fund - Regular Plan - Growth Option'}
# FluxRecord() table: 1, {'result': '_result', 'table': 1, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 20.9633, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Active Debt Multi Manager FoF Scheme - DIRECT - IDCW'}
# FluxRecord() table: 2, {'result': '_result', 'table': 2, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 33.478, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Active Debt Multi Manager FoF Scheme - Direct Plan - Growth Option'}
# FluxRecord() table: 3, {'result': '_result', 'table': 3, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 20.0062, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Active Debt Multi Manager FoF Scheme - REGULAR - IDCW'}
# FluxRecord() table: 4, {'result': '_result', 'table': 4, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 31.901, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Active Debt Multi Manager FoF Scheme - Regular Plan - Growth Option'}
# FluxRecord() table: 5, {'result': '_result', 'table': 5, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 22.979, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Asset Allocator FoF- Direct Plan - Growth Option'}
# FluxRecord() table: 6, {'result': '_result', 'table': 6, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 44.5539, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Asset Allocator FoF- Regular Plan - Growth Option'}
# FluxRecord() table: 7, {'result': '_result', 'table': 7, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 21.8966, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Asset Allocator FoF-DIRECT - IDCW'}
# FluxRecord() table: 8, {'result': '_result', 'table': 8, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 41.028, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Asset Allocator FoF-REGULAR - IDCW'}
# FluxRecord() table: 9, {'result': '_result', 'table': 9, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 35.1711, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Financial Planning Fund - Aggressive Plan - Direct - IDCW'}
# FluxRecord() table: 10, {'result': '_result', 'table': 10, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 38.4046, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Financial Planning Fund - Aggressive Plan - Direct Plan - Growth Option'}
# FluxRecord() table: 11, {'result': '_result', 'table': 11, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 35.5581, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Financial Planning Fund - Aggressive Plan - Regular Plan - Growth Option'}
# FluxRecord() table: 12, {'result': '_result', 'table': 12, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 32.5475, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Financial Planning Fund - Aggressive Plan -Regular - IDCW'}
# FluxRecord() table: 13, {'result': '_result', 'table': 13, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 27.1054, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Financial Planning Fund - Conservative Plan - Direct Plan - Growth Option'}
# FluxRecord() table: 14, {'result': '_result', 'table': 14, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 18.4039, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Financial Planning Fund - Conservative Plan -Direct - IDCW'}
# FluxRecord() table: 15, {'result': '_result', 'table': 15, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 23.4102, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Financial Planning Fund - Conservative Plan -Regular - IDCW'}
# FluxRecord() table: 16, {'result': '_result', 'table': 16, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 31.4164, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Financial Planning Fund - Moderate Plan - Direct Plan - Growth Option'}
# FluxRecord() table: 17, {'result': '_result', 'table': 17, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 29.7366, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Financial Planning Fund - Moderate Plan - Regular Plan - Growth Option'}
# FluxRecord() table: 18, {'result': '_result', 'table': 18, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 28.486, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Financial Planning Fund -Moderate Plan - Direct - IDCW'}
# FluxRecord() table: 19, {'result': '_result', 'table': 19, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 26.6717, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Financial Planning Fund -Moderate Plan - Regular - IDCW'}
# FluxRecord() table: 20, {'result': '_result', 'table': 20, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 17.2343, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Global Emerging Opportunities Fund - Direct - IDCW'}
# FluxRecord() table: 21, {'result': '_result', 'table': 21, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 19.4859, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Global Emerging Opportunities Fund - Direct plan - Growth Option'}
# FluxRecord() table: 22, {'result': '_result', 'table': 22, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 18.8505, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Global Emerging Opportunities Fund - Regular - IDCW'}
# FluxRecord() table: 23, {'result': '_result', 'table': 23, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 24.0222, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Global Excellence Equity Fund Of Fund - Retail Plan - Direct Plan - Growth Option'}
# FluxRecord() table: 24, {'result': '_result', 'table': 24, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 22.8893, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Global Excellence Equity Fund Of Fund- Retail Plan - Regular Plan - Growth Option'}
# FluxRecord() table: 25, {'result': '_result', 'table': 25, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 24.0428, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Global Excellence Equity Fund Of Fund-DIRECT - RETAIL - IDCW'}
# FluxRecord() table: 26, {'result': '_result', 'table': 26, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 22.9038, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Global Excellence Equity Fund Of Fund-REGULAR - RETAIL - IDCW'}
# FluxRecord() table: 27, {'result': '_result', 'table': 27, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 18.7153, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Gold Fund - Growth - Direct Plan'}
# FluxRecord() table: 28, {'result': '_result', 'table': 28, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 18.7179, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Gold Fund-DIRECT - IDCW'}
# FluxRecord() table: 29, {'result': '_result', 'table': 29, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 18.1434, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Gold Fund-Growth'}
# FluxRecord() table: 30, {'result': '_result', 'table': 30, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 18.1426, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Gold Fund-REGULAR - IDCW'}
# FluxRecord() table: 31, {'result': '_result', 'table': 31, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 10.37, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Multi - Index Fund of Funds-Direct Growth'}
# FluxRecord() table: 32, {'result': '_result', 'table': 32, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 10.37, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Multi- Index Fund Of Fund-Direct IDCW'}
# FluxRecord() table: 33, {'result': '_result', 'table': 33, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 10.3415, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Multi- Index Fund Of Fund-Regular IDCW'}
# FluxRecord() table: 34, {'result': '_result', 'table': 34, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 10.3416, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Multi-Index Fund Of Fund-Regular Growth'}
# FluxRecord() table: 35, {'result': '_result', 'table': 35, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 8.8206, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Nasdaq 100 FOF-Direct IDCW'}
# FluxRecord() table: 36, {'result': '_result', 'table': 36, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 8.8193, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Nasdaq 100 FOF-Direct-Growth'}
# FluxRecord() table: 37, {'result': '_result', 'table': 37, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 8.7608, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Nasdaq 100 FOF-Regular Growth'}
# FluxRecord() table: 38, {'result': '_result', 'table': 38, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 8.7601, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Nasdaq 100 FOF-Regular IDCW'}
# FluxRecord() table: 39, {'result': '_result', 'table': 39, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 12.0249, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Silver ETF FOF-Direct Growth'}
# FluxRecord() table: 40, {'result': '_result', 'table': 40, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 12.022, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Silver ETF FOF-Direct IDCW'}
# FluxRecord() table: 41, {'result': '_result', 'table': 41, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 11.9427, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Silver ETF FOF-Regular Growth'}
# FluxRecord() table: 42, {'result': '_result', 'table': 42, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 11.9407, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun Life Silver ETF FOF-Regular IDCW'}
# FluxRecord() table: 43, {'result': '_result', 'table': 43, '_start': datetime.datetime(2023, 5, 2, 23, 27, 57, 327157, tzinfo=tzutc()), '_stop': datetime.datetime(2023, 5, 3, 23, 27, 57, 327157, tzinfo=tzutc()), '_time': datetime.datetime(2023, 5, 3, 9, 13, 25, tzinfo=tzutc()), '_value': 25.7314, '_field': 'nav', '_measurement': 'Aditya Birla Sun Life Mutual Fund', 'db_record_time': '1683174677185', 'mutual_fund_name': 'Aditya Birla Sun life Financial Planning Fund - Conservative Plan - Regular Plan - Growth Option'}
